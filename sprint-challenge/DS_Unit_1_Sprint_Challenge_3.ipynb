# %% [markdown]
# # Data Science Unit 1 Sprint Challenge 3 - Carlos Gutierrez
#
# # Creating Professional Portfolios
#
# For your Sprint Challenge, you will **write about your upcoming [data storytelling portfolio project](https://learn.lambdaschool.com/ds/module/recedjanlbpqxic2r)**.
#
# (Don't worry, you don't have to choose your final idea now. For this challenge, you can write about any idea you're considering.)

# %% [markdown]
# # Part 1
#
# **Describe an idea** you could work on for your upcoming data storytelling project. What's your hypothesis?
#
# #### Write a [lede](https://www.thoughtco.com/how-to-write-a-great-lede-2074346) (first paragraph)
# - Put the bottom line up front.
# - Use 60 words or fewer. (The [Hemingway App](http://www.hemingwayapp.com/) gives you word count.)
#
# [This is hard](https://quoteinvestigator.com/2012/04/28/shorter-letter/), but you can do it!
#
# #### Stretch goals
# - Write more about your idea. Tell us what the story's about. Show us why it's interesting. Continue to follow the inverted pyramid structure.
# - Improve your readability. Post your "before & after" scores from the Hemingway App.

# %% [markdown]
# # The Rise Technology in Football - Analyzing VAR in Europe's Top Leagues
#
#
# ![football.jpg](attachment:football.jpg)
#
#
#
# > #### _All major European Football leagues except the Premier League have implemented VAR. How have they done so far? Has VAR improved fairness in the game? Here's a comparison of games with VAR and games in the previous 5 seasons to give us a clue._
#
#
# According to an [article by ESPN](http://www.espn.com/soccer/blog/espn-fc-united/68/post/3711406/shaka-hislop-power-rankings-juventus-overtake-manchester-city-at-the-top-as-dutch-duo-fall) written in September VAR already has positively impacted the top European Leagues implementing this technology, yet controversy still remains. For example, although in Spain's La Liga bookings have reached the lowest since the 1991-1992 season (4.34 bookings per game) many fans and commentators complain on how offsides and plays leading to goals are being evaluated.
#
# Moreover Germany's Bundesliga began using VAR last season. In total VAR review awarded 26 penaties and overturned 13. Moreover on Bundesliga's first week of matches this season controversy was sparked. In the match between Wolfsburg and Shalke VAR influenced in reversing two of the referees decisions. The first turned a booking from yellow to red, while the other after from red to yellow. _Something truly uncommon._
#
# ## Analizing VAR
#
# ### France's Ligue 1
#
# ### Germany's Bundesliga
#
# ### Spain's La Liga

# %% [markdown]
# # Part 2
#
# #### Find sources
# - Link to at least 2 relevant sources for your topic. Sources could include any data or writing about your topic.
# - Use [Markdown](https://commonmark.org/help/) to format your links.
# - Summarize each source in 1-2 sentences.
#
# #### Stretch goals
# - Find more sources.
# - Use Markdown to add images from your sources.
# - Critically evaluate your sources in writing.

# %% [markdown]
# #### _Sources Found_
# Most Football (Soccer) statistical sources are very generalistic. Deep statistical analysis is fairly new to the game. In order to find detailed statistics one has to tap into paid resources used by major teams and media. These are the source I found after days of searching that will help me in my analysis:
#
# * [FootballAPI.com](https://football-api.com/documentation2/#!/Competitions/get_competitions):
# > __This is the source I plan to use__. It's a paid API service that provides data in JSON format. This is one of the cheapest paid APIs I have found. I already became a member and began looking into some of the leagues and the numbers I need from each match.
# * [Footystats.org](https://footystats.org/):
# > This is one many websites that shows statistics for match played. The inconvenience with this option is that I would have to scrape the data for each team in each of the seasons I want to analyze. It may take me a really long time.

# %% [markdown]
# # Part 3
#
# #### Plan your next steps
# - Describe at least 2 actions you'd take to get started with your project.
# - Use Markdown headings and lists to organize your plan.
#
# #### Stretch goals
# - Add detail to your plan.
# - Publish your project proposal on your GitHub Pages site.

# %% [markdown]
# #### _Steps to take_
# I have taken a general look into the data. It will be a somewhat laborious task. These are the stats I plan on finding:
#
# * Stats for seasons before VAR
# > * Offsides
# > * Bookings (yellow and red cards)
# > * Penaties
# > * Average game length
#
# * Stats for season(s) after VAR
# > * Offsides
# > * Bookings (yellow and red cards)
# > * Penaties
# > * Average game length
# > * _Number of VAR intervensions_
# > * _Reverse on-field decisions after VAR intervensions_
#
# These last two stats in seasons with VAR will depend on searches on each of the games commentaries where 'VAR' is mentioned.
